# %% [markdown]
# <a href="https://colab.research.google.com/github/KonradBier/kBI/blob/master/Case_Study_dane_finansowe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.graph_objects as go

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetch stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

# %%
df_amzn = fetch_financial_data(company='AMZN')
df_aapl = fetch_financial_data(company='AAPL')
df_msft = fetch_financial_data(company='MSFT')
df_nflx = fetch_financial_data(company='NFLX')
df_twtr = fetch_financial_data(company='TWTR')

# %%
df_amzn.head(2)
# Out:
#                Open       High      Low    Close   Volume
# Date
# 2020-07-22  3125.00  3149.9999  3065.26  3099.91  4104225
# 2020-07-21  3232.49  3240.5758  3105.72  3138.29  6134965

# %%
import pandas as pd

df = pd.concat([df_amzn.Close, df_aapl.Close, df_msft.Close, df_nflx.Close, df_twtr.Close], axis=1, join='inner')
df.columns = ['amazon', 'apple', 'microsoft', 'netflix', 'twitter']
df = df.reset_index()
df.head()
# Out:
#         Date   amazon   apple  microsoft  netflix  twitter
# 0 2020-07-22  3099.91  389.09     211.75   489.82    36.94
# 1 2020-07-21  3138.29  388.00     208.75   490.10    37.01
# 2 2020-07-20  3196.84  393.43     211.60   502.41    37.06
# 3 2020-07-17  2961.97  385.31     202.88   492.99    35.81
# 4 2020-07-16  2999.90  386.09     203.92   527.39    35.28

# %%
trace0 = go.Scatter(x= df.Date, y= df.amazon, name='amazon')
trace1 = go.Scatter(x= df.Date, y= df.apple, name='apple')
trace2 = go.Scatter(x= df.Date, y= df.microsoft, name='microsoft')
trace3 = go.Scatter(x= df.Date, y= df.netflix, name='netflix')
trace4 = go.Scatter(x= df.Date, y= df.twitter, name='twitter')

data= [trace0, trace1, trace2, trace3, trace4]

layout = go.Layout(yaxis_type='log')
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c2bccace-584a-4705-9295-8e94ac7ad6a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c2bccace-584a-4705-9295-8e94ac7ad6a7")) {
#                     Plotly.newPlot(
#                         'c2bccace-584a-4705-9295-8e94ac7ad6a7',
# ...

# %%
data = [go.Scatter(x=df.Date, y=df[col], name=col) for col in df.columns[1:]]   #list comprehension
layout = go.Layout(yaxis_type='log')
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e233c88c-de3c-42cc-93cd-6e8198b06744" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e233c88c-de3c-42cc-93cd-6e8198b06744")) {
#                     Plotly.newPlot(
#                         'e233c88c-de3c-42cc-93cd-6e8198b06744',
# ...

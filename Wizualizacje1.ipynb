# %% [markdown]
# <a href="https://colab.research.google.com/github/KonradBier/kBI/blob/master/Wizualizacje1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
x = np.linspace(0,20,100)
y = np.random.rand(100, 4)
y = np.cumsum(y,axis = 0)

# %%
plt.plot(x, y)
# Out:
# [<matplotlib.lines.Line2D at 0x7f06512a8dd8>,
#  <matplotlib.lines.Line2D at 0x7f06512a8ef0>,
#  <matplotlib.lines.Line2D at 0x7f06512b2080>,
#  <matplotlib.lines.Line2D at 0x7f06512b21d0>]
